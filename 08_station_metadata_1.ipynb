# %% [markdown]
# Now we want to load the station metadata available from GIOŚ

# %%
import pandas as pd

df_meta = pd.read_excel("./meta.xlsx", decimal=",")
df_meta.set_index("Nr", inplace=True, drop=True)
df_meta.columns = (
    df_meta.columns
    .str.strip()
    .str.lower()
    .str.replace(r'\s+', '_', regex=True)
)
df_meta = df_meta.rename(columns={
    'stary_kod_stacji_(o_ile_inny_od_aktualnego)': 'stary_kod',
    'wgs84_φ_n': 'lat',
    'wgs84_λ_e': 'lon'
})

# %%
df_meta.reset_index(inplace=True)
df_meta.set_index('kod_stacji', inplace=True)
df_meta
# Out:
#                    Nr kod_międzynarodowy                    nazwa_stacji  \
# kod_stacji
# DsBialka            1                NaN                          Białka
# DsBielGrot          2                NaN  Bielawa - ul. Grota Roweckiego
# DsBogatFrancMOB     3            PL0602A                 Bogatynia Mobil
# DsBogChop           4            PL0315A             Bogatynia - Chopina
# DsBogZatonieMob     5            PL0576A               Bogatynia - Mobil
# ...               ...                ...                             ...
# ZpSzczPilsud     1112            PL0249A      Szczecin, ul. Piłsudskiego
# ZpSzczWSSEEnerg  1113                NaN                     Energetyków
# ZpSzczWSSESped6  1114                NaN                     Spedytorska
# ZpWalWalczWSSE   1115                NaN                           Wałcz
# ZpWiduBulRyb     1116            PL0182A                       Widuchowa
#
#                                    stary_kod data_uruchomienia  \
# kod_stacji
# DsBialka                                 NaN        1990-01-03
# DsBielGrot                               NaN        1994-01-02
# DsBogatFrancMOB                   DsBogatMob        2015-01-01
# DsBogChop                                NaN        1996-01-01
# DsBogZatonieMob                          NaN        2012-01-01
# ...                                      ...               ...
# ZpSzczPilsud     ZpSzczecin002, ZpSzczPils02        2004-12-31
# ZpSzczWSSEEnerg                          NaN        1992-01-01
# ZpSzczWSSESped6                          NaN        1992-01-01
# ZpWalWalczWSSE                           NaN        1992-01-01
# ZpWiduBulRyb              ZpGryfWiduchowa003        2003-01-01
#
#                 data_zamknięcia     typ_stacji  typ_obszaru  \
# kod_stacji
# DsBialka             2005-12-31    przemysłowa   podmiejski
# DsBielGrot           2003-12-31            tło      miejski
# DsBogatFrancMOB      2015-12-31            tło      miejski
# DsBogChop            2013-12-31    przemysłowa      miejski
# DsBogZatonieMob      2012-12-31    przemysłowa      miejski
# ...                         ...            ...          ...
# ZpSzczPilsud                NaT  komunikacyjna      miejski
# ZpSzczWSSEEnerg      2003-12-31  komunikacyjna      miejski
# ZpSzczWSSESped6      2004-01-01            tło      miejski
# ZpWalWalczWSSE       2005-01-01            tło      miejski
# ZpWiduBulRyb                NaT            tło  pozamiejski
#
#                            rodzaj_stacji         województwo miejscowość  \
# kod_stacji
# DsBialka         kontenerowa stacjonarna        DOLNOŚLĄSKIE      Białka
# DsBielGrot                     w budynku        DOLNOŚLĄSKIE     Bielawa
# DsBogatFrancMOB                  mobilna        DOLNOŚLĄSKIE   Bogatynia
# DsBogChop        kontenerowa stacjonarna        DOLNOŚLĄSKIE   Bogatynia
# DsBogZatonieMob                  mobilna        DOLNOŚLĄSKIE   Bogatynia
# ...                                  ...                 ...         ...
# ZpSzczPilsud     kontenerowa stacjonarna  ZACHODNIOPOMORSKIE    Szczecin
# ZpSzczWSSEEnerg                w budynku  ZACHODNIOPOMORSKIE    Szczecin
# ZpSzczWSSESped6  kontenerowa stacjonarna  ZACHODNIOPOMORSKIE    Szczecin
# ZpWalWalczWSSE                 w budynku  ZACHODNIOPOMORSKIE       Wałcz
# ZpWiduBulRyb     kontenerowa stacjonarna  ZACHODNIOPOMORSKIE   Widuchowa
#
#                                   adres        lat        lon
# kod_stacji
# DsBialka                            NaN  51.197783  16.117390
# DsBielGrot       ul. Grota Roweckiego 6  50.682510  16.617348
# DsBogatFrancMOB     ul. Francuska/Kręta  50.940998  14.916790
# DsBogChop                ul. Chopina 35  50.905856  14.967175
# DsBogZatonieMob    ul. Konrada, Zatonie  50.943245  14.913327
# ...                                 ...        ...        ...
# ZpSzczPilsud         ul. Piłsudskiego 1  53.432169  14.553900
# ZpSzczWSSEEnerg       ul. Energetyków 2  53.420475  14.561934
# ZpSzczWSSESped6       ul. Spedytorska 6  53.415043  14.555347
# ZpWalWalczWSSE          ul. Bydgoska 86  53.263667  16.492596
# ZpWiduBulRyb     ul. Bulwary Rybackie 1  53.122325  14.382245
#
# [1116 rows x 14 columns]

# %%
df_stacje = pd.read_csv("stations_complete_2016_2019.csv", index_col=0, parse_dates=True)

stacje_w_csv = df_stacje.columns

df_meta = df_meta.loc[df_meta.index.intersection(stacje_w_csv), ["lat", "lon"]]

# %%
import osmnx as ox
print(ox.__version__)
# Out:
# 2.0.6

# %% [markdown]
# Now we want to add some additional informations to station metadata;
#
# We will use open street map to extract some important features:

# %%
import geopandas as gpd
import pandas as pd
import osmnx as ox
from shapely.geometry import Point
import numpy as np

# konfiguracja
ox.settings.use_cache = True
ox.settings.log_console = False

buffer_radius = 5000  # m

def compute_features(lat, lon, buffer_radius=2000):
    try:
        pt = Point(lon, lat)  # shapely: (lon, lat)
        buffer_poly = ox.utils_geo.buffer_geometry(pt, buffer_radius)

        buffer_3857 = gpd.GeoSeries([buffer_poly], crs="EPSG:4326").to_crs(epsg=3857).iloc[0]
        pt_3857 = gpd.GeoSeries([pt], crs="EPSG:4326").to_crs(epsg=3857).iloc[0]

        # === DROGI ===
        try:
            G = ox.graph_from_point((lat, lon), dist=buffer_radius, network_type="drive")
            _, edges = ox.graph_to_gdfs(G)
            edges = edges.to_crs(epsg=3857)

            edges_in = edges[edges.geometry.intersects(buffer_3857)]
            total_road_length_km = edges_in.length.sum() / 1000 if not edges_in.empty else np.nan
            nearest_road_dist_m = edges_in.distance(pt_3857).min() if not edges_in.empty else np.nan

        except Exception as e:
            print(f"[Błąd dróg] ({lat}, {lon}): {e}")
            total_road_length_km = np.nan
            nearest_road_dist_m = np.nan

        try:
            buildings = ox.features_from_polygon(buffer_poly, tags={"building": True})
            buildings = buildings[buildings.geometry.geom_type.isin(["Polygon", "MultiPolygon"])]

            buildings = buildings.to_crs(epsg=3857)
            buildings_in = buildings[buildings.geometry.intersects(buffer_3857)]
            building_count = len(buildings_in) if not buildings_in.empty else 0

        except Exception as e:
            print(f"[Błąd budynków] ({lat}, {lon}): {e}")
            building_count = np.nan

        return nearest_road_dist_m, total_road_length_km, building_count

    except Exception as e:
        print(f"[Błąd ogólny] ({lat}, {lon}): {e}")
        return np.nan, np.nan, np.nan


nearest_road_dist_list = []
total_road_length_list = []
building_count_list = []
x = 1
for i, row in df_meta.iterrows():
    nr, trl, bc = compute_features(row.lat, row.lon, buffer_radius)
    nearest_road_dist_list.append(nr)
    total_road_length_list.append(trl)
    building_count_list.append(bc)
    print(f"Przetworzono {x}/{len(df_meta)} lokalizacji")
    x+=1

df_meta["nearest_road_dist_m"] = nearest_road_dist_list
df_meta["total_road_length_km"] = total_road_length_list
df_meta["building_count"] = building_count_list

print(df_meta)
# Out:
# Przetworzono 1/61 lokalizacji
# Przetworzono 2/61 lokalizacji
# Przetworzono 3/61 lokalizacji
# Przetworzono 4/61 lokalizacji
# Przetworzono 5/61 lokalizacji
# Przetworzono 6/61 lokalizacji
# Przetworzono 7/61 lokalizacji
# Przetworzono 8/61 lokalizacji
# Przetworzono 9/61 lokalizacji
# Przetworzono 10/61 lokalizacji
# Przetworzono 11/61 lokalizacji
# Przetworzono 12/61 lokalizacji
# Przetworzono 13/61 lokalizacji
# Przetworzono 14/61 lokalizacji
# Przetworzono 15/61 lokalizacji
# Przetworzono 16/61 lokalizacji
# Przetworzono 17/61 lokalizacji
# Przetworzono 18/61 lokalizacji
# Przetworzono 19/61 lokalizacji
# Przetworzono 20/61 lokalizacji
# Przetworzono 21/61 lokalizacji
# [Błąd budynków] (49.619281, 20.714403): HTTPSConnectionPool(host='overpass-api.de', port=443): Max retries exceeded with url: /api/interpreter (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000160B83B36D0>, 'Connection to overpass-api.de timed out. (connect timeout=180)'))
# Przetworzono 22/61 lokalizacji
# Przetworzono 23/61 lokalizacji
# Przetworzono 24/61 lokalizacji
# [Błąd budynków] (49.293564, 19.960083): HTTPSConnectionPool(host='overpass-api.de', port=443): Max retries exceeded with url: /api/interpreter (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000160B83B6290>, 'Connection to overpass-api.de timed out. (connect timeout=180)'))
# Przetworzono 25/61 lokalizacji
# [Błąd dróg] (52.556279, 19.687672): HTTPSConnectionPool(host='overpass-api.de', port=443): Max retries exceeded with url: /api/interpreter (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000160B8516050>, 'Connection to overpass-api.de timed out. (connect timeout=180)'))
# Przetworzono 26/61 lokalizacji
# Przetworzono 27/61 lokalizacji
# Przetworzono 28/61 lokalizacji
# Przetworzono 29/61 lokalizacji
# Przetworzono 30/61 lokalizacji
# Przetworzono 31/61 lokalizacji
# Przetworzono 32/61 lokalizacji
# Przetworzono 33/61 lokalizacji
# Przetworzono 34/61 lokalizacji
# Przetworzono 35/61 lokalizacji
# Przetworzono 36/61 lokalizacji
# Przetworzono 37/61 lokalizacji
# Przetworzono 38/61 lokalizacji
# Przetworzono 39/61 lokalizacji
# [Błąd budynków] (50.453621, 20.71564): HTTPSConnectionPool(host='overpass-api.de', port=443): Max retries exceeded with url: /api/interpreter (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000160B66BA3D0>, 'Connection to overpass-api.de timed out. (connect timeout=180)'))
# Przetworzono 40/61 lokalizacji
# Przetworzono 41/61 lokalizacji
# Przetworzono 42/61 lokalizacji
# Przetworzono 43/61 lokalizacji
# Przetworzono 44/61 lokalizacji
# Przetworzono 45/61 lokalizacji
# Przetworzono 46/61 lokalizacji
# Przetworzono 47/61 lokalizacji
# Przetworzono 48/61 lokalizacji
# Przetworzono 49/61 lokalizacji
# Przetworzono 50/61 lokalizacji
# Przetworzono 51/61 lokalizacji
# [Błąd dróg] (54.167847, 19.410942): HTTPSConnectionPool(host='overpass-api.de', port=443): Max retries exceeded with url: /api/interpreter (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000160B3CB02D0>, 'Connection to overpass-api.de timed out. (connect timeout=180)'))
# [Błąd budynków] (54.167847, 19.410942): HTTPSConnectionPool(host='overpass-api.de', port=443): Max retries exceeded with url: /api/interpreter (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000160B9133650>, 'Connection to overpass-api.de timed out. (connect timeout=180)'))
# Przetworzono 52/61 lokalizacji
# Przetworzono 53/61 lokalizacji
# Przetworzono 54/61 lokalizacji
# [Błąd budynków] (54.124819, 22.038056): HTTPSConnectionPool(host='overpass-api.de', port=443): Max retries exceeded with url: /api/interpreter (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000160B5A1BD50>, 'Connection to overpass-api.de timed out. (connect timeout=180)'))
# Przetworzono 55/61 lokalizacji
# [Błąd dróg] (51.74795, 18.049063): HTTPSConnectionPool(host='overpass-api.de', port=443): Max retries exceeded with url: /api/interpreter (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000160B823AF50>, 'Connection to overpass-api.de timed out. (connect timeout=180)'))
# Przetworzono 56/61 lokalizacji
# Przetworzono 57/61 lokalizacji
# Przetworzono 58/61 lokalizacji
# Przetworzono 59/61 lokalizacji
# Przetworzono 60/61 lokalizacji
# Przetworzono 61/61 lokalizacji
#                     lat        lon  nearest_road_dist_m  total_road_length_km  \
# DsLegAlRzecz  51.204503  16.180513            98.613062            942.949585
# DsOsieczow21  51.317630  15.431719            40.258760            148.954010
# DsWalbrzWyso  50.768729  16.269677           170.100903            817.813995
# DsWrocNaGrob  51.103456  17.059225            97.176639           1518.020860
# DsZgorBohGet  51.150391  15.008175           138.987771            988.524194
# ...                 ...        ...                  ...                   ...
# WpPleszAlMic  51.884922  17.791106            86.378906            518.121034
# ZpKoszSpasow  54.207151  16.193236            27.102665           1019.729752
# ZpMyslZaBram  52.926283  14.862809            15.499193            290.059223
# ZpSzczAndrze  53.380975  14.663347            26.632511            653.938328
# ZpSzczec1Maj  53.712114  16.692517            23.818303            544.823893
#
#               building_count
# DsLegAlRzecz         15745.0
# DsOsieczow21          2334.0
# DsWalbrzWyso         15897.0
# DsWrocNaGrob         60249.0
# DsZgorBohGet         28363.0
# ...                      ...
# WpPleszAlMic          9820.0
# ZpKoszSpasow         15411.0
# ZpMyslZaBram          4069.0
# ZpSzczAndrze         12399.0
# ZpSzczec1Maj          8120.0
#
# [61 rows x 5 columns]

# %%
'''
import requests

try:
    r = requests.get("https://overpass-api.de/api/interpreter")
    print(r.status_code)
except Exception as e:
    print("Błąd sieci:", e)
'''
# Out:
# 400

# %%
from IPython.display import display, HTML

# przykład dla DataFrame
display(HTML(f"<div style='max-height:300px; overflow:auto;'>{df_meta.to_html()}</div>"))

df_meta
df_meta.to_csv('metadata5000.csv')
# Out:
# <div style='max-height:300px; overflow:auto;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>nearest_road_dist_m</th>
#       <th>total_road_length_km</th>
#       <th>building_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>DsLegAlRzecz</th>
#       <td>51.204503</td>
#       <td>16.180513</td>
#       <td>98.613062</td>
#       <td>942.949585</td>
#       <td>15745.0</td>
#     </tr>
#     <tr>
#       <th>DsOsieczow21</th>
#       <td>51.317630</td>
#       <td>15.431719</td>
#       <td>40.258760</td>
#       <td>148.954010</td>
#       <td>2334.0</td>
#     </tr>
#     <tr>
#       <th>DsWalbrzWyso</th>
#       <td>50.768729</td>
#       <td>16.269677</td>
#       <td>170.100903</td>
#       <td>817.813995</td>
#       <td>15897.0</td>
#     </tr>
#     <tr>
#       <th>DsWrocNaGrob</th>
#       <td>51.103456</td>
#       <td>17.059225</td>
#       <td>97.176639</td>
#       <td>1518.020860</td>
#       <td>60249.0</td>
#     </tr>
#     <tr>
#       <th>DsZgorBohGet</th>
#       <td>51.150391</td>
#       <td>15.008175</td>
#       <td>138.987771</td>
#       <td>988.524194</td>
#       <td>28363.0</td>
#     </tr>
#     <tr>
#       <th>KpBydFieldor</th>
#       <td>53.151452</td>
#       <td>18.132062</td>
#       <td>22.380118</td>
#       <td>711.014879</td>
#       <td>8995.0</td>
#     </tr>
#     <tr>
#       <th>KpGrudSienki</th>
#       <td>53.491831</td>
#       <td>18.752503</td>
#       <td>108.389527</td>
#       <td>765.180131</td>
#       <td>22104.0</td>
#     </tr>
#     <tr>
#       <th>KpToruDziewu</th>
#       <td>53.028647</td>
#       <td>18.666103</td>
#       <td>97.101206</td>
#       <td>1339.475703</td>
#       <td>21483.0</td>
#     </tr>
#     <tr>
#       <th>KpZielBoryTu</th>
#       <td>53.662117</td>
#       <td>17.934017</td>
#       <td>155.819124</td>
#       <td>123.469175</td>
#       <td>665.0</td>
#     </tr>
#     <tr>
#       <th>LbBiaPodOrze</th>
#       <td>52.029194</td>
#       <td>23.149389</td>
#       <td>28.987375</td>
#       <td>888.236469</td>
#       <td>16920.0</td>
#     </tr>
#     <tr>
#       <th>LbChelJagiel</th>
#       <td>51.130950</td>
#       <td>23.514603</td>
#       <td>32.203574</td>
#       <td>763.408153</td>
#       <td>15088.0</td>
#     </tr>
#     <tr>
#       <th>LbLubSliwins</th>
#       <td>51.273078</td>
#       <td>22.551675</td>
#       <td>73.295668</td>
#       <td>1620.709864</td>
#       <td>28988.0</td>
#     </tr>
#     <tr>
#       <th>LbZamoHrubie</th>
#       <td>50.716628</td>
#       <td>23.290247</td>
#       <td>49.634154</td>
#       <td>809.140780</td>
#       <td>17611.0</td>
#     </tr>
#     <tr>
#       <th>LdLodzCzerni</th>
#       <td>51.758050</td>
#       <td>19.529786</td>
#       <td>110.091454</td>
#       <td>1384.584774</td>
#       <td>32623.0</td>
#     </tr>
#     <tr>
#       <th>LdLodzLegion</th>
#       <td>51.776417</td>
#       <td>19.452936</td>
#       <td>37.578384</td>
#       <td>1859.101610</td>
#       <td>57117.0</td>
#     </tr>
#     <tr>
#       <th>LdPioTrKraPr</th>
#       <td>51.404406</td>
#       <td>19.696956</td>
#       <td>49.362299</td>
#       <td>940.236024</td>
#       <td>18860.0</td>
#     </tr>
#     <tr>
#       <th>LuGorzPilsud</th>
#       <td>52.747044</td>
#       <td>15.246294</td>
#       <td>223.310025</td>
#       <td>1039.190473</td>
#       <td>23111.0</td>
#     </tr>
#     <tr>
#       <th>LuZarySzyman</th>
#       <td>51.642656</td>
#       <td>15.127808</td>
#       <td>110.791073</td>
#       <td>599.697384</td>
#       <td>11614.0</td>
#     </tr>
#     <tr>
#       <th>LuZielKrotka</th>
#       <td>51.939783</td>
#       <td>15.518861</td>
#       <td>25.056820</td>
#       <td>1101.224200</td>
#       <td>21051.0</td>
#     </tr>
#     <tr>
#       <th>MpBochKonfed</th>
#       <td>49.969017</td>
#       <td>20.439511</td>
#       <td>12.025842</td>
#       <td>783.667809</td>
#       <td>14474.0</td>
#     </tr>
#     <tr>
#       <th>MpKrakBujaka</th>
#       <td>50.010575</td>
#       <td>19.949189</td>
#       <td>38.535320</td>
#       <td>1600.690043</td>
#       <td>45528.0</td>
#     </tr>
#     <tr>
#       <th>MpNoSaczNadb</th>
#       <td>49.619281</td>
#       <td>20.714403</td>
#       <td>217.636022</td>
#       <td>1107.655265</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>MpTarBitStud</th>
#       <td>50.020169</td>
#       <td>21.004167</td>
#       <td>31.005101</td>
#       <td>1231.287945</td>
#       <td>22721.0</td>
#     </tr>
#     <tr>
#       <th>MpTrzebOsZWM</th>
#       <td>50.159406</td>
#       <td>19.477464</td>
#       <td>46.772680</td>
#       <td>639.941377</td>
#       <td>13759.0</td>
#     </tr>
#     <tr>
#       <th>MpZakopaSien</th>
#       <td>49.293564</td>
#       <td>19.960083</td>
#       <td>193.943484</td>
#       <td>429.647756</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>MzPlocKroJad</th>
#       <td>52.556279</td>
#       <td>19.687672</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>16202.0</td>
#     </tr>
#     <tr>
#       <th>MzRadHallera</th>
#       <td>51.415324</td>
#       <td>21.171285</td>
#       <td>166.962547</td>
#       <td>1432.618227</td>
#       <td>37640.0</td>
#     </tr>
#     <tr>
#       <th>MzWarKondrat</th>
#       <td>52.290864</td>
#       <td>21.042458</td>
#       <td>131.015057</td>
#       <td>1651.564140</td>
#       <td>32941.0</td>
#     </tr>
#     <tr>
#       <th>MzWarWokalna</th>
#       <td>52.160772</td>
#       <td>21.033819</td>
#       <td>257.648262</td>
#       <td>1698.648574</td>
#       <td>25251.0</td>
#     </tr>
#     <tr>
#       <th>OpKluczMicki</th>
#       <td>50.972181</td>
#       <td>18.207575</td>
#       <td>228.059519</td>
#       <td>504.617552</td>
#       <td>9836.0</td>
#     </tr>
#     <tr>
#       <th>OpOpoleOsAKr</th>
#       <td>50.676856</td>
#       <td>17.950278</td>
#       <td>296.021447</td>
#       <td>1032.870120</td>
#       <td>25485.0</td>
#     </tr>
#     <tr>
#       <th>PdBialWarsza</th>
#       <td>53.129306</td>
#       <td>23.181744</td>
#       <td>305.461035</td>
#       <td>1732.771180</td>
#       <td>34926.0</td>
#     </tr>
#     <tr>
#       <th>PdLomSikorsk</th>
#       <td>53.181394</td>
#       <td>22.054381</td>
#       <td>42.572434</td>
#       <td>799.896652</td>
#       <td>16502.0</td>
#     </tr>
#     <tr>
#       <th>PkJasloSikor</th>
#       <td>49.744886</td>
#       <td>21.454617</td>
#       <td>17.311975</td>
#       <td>737.736878</td>
#       <td>17077.0</td>
#     </tr>
#     <tr>
#       <th>PkKrosKletow</th>
#       <td>49.690169</td>
#       <td>21.749700</td>
#       <td>151.998078</td>
#       <td>825.462911</td>
#       <td>20298.0</td>
#     </tr>
#     <tr>
#       <th>PkNiskoSzkla</th>
#       <td>50.529892</td>
#       <td>22.112467</td>
#       <td>12.798185</td>
#       <td>621.648386</td>
#       <td>12447.0</td>
#     </tr>
#     <tr>
#       <th>PkRzeszRejta</th>
#       <td>50.024242</td>
#       <td>22.010575</td>
#       <td>70.808989</td>
#       <td>1495.991239</td>
#       <td>40593.0</td>
#     </tr>
#     <tr>
#       <th>PmGdaPowWiel</th>
#       <td>54.398639</td>
#       <td>18.614333</td>
#       <td>164.603097</td>
#       <td>1146.518474</td>
#       <td>25932.0</td>
#     </tr>
#     <tr>
#       <th>PmKosTargowa</th>
#       <td>54.120694</td>
#       <td>17.975861</td>
#       <td>34.574882</td>
#       <td>698.759853</td>
#       <td>10644.0</td>
#     </tr>
#     <tr>
#       <th>SkBuskRokosz</th>
#       <td>50.453621</td>
#       <td>20.715640</td>
#       <td>188.513671</td>
#       <td>600.829401</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>SkKielWarsza</th>
#       <td>50.894374</td>
#       <td>20.657988</td>
#       <td>39.110653</td>
#       <td>1079.549713</td>
#       <td>24496.0</td>
#     </tr>
#     <tr>
#       <th>SkStaraZlota</th>
#       <td>51.050611</td>
#       <td>21.084175</td>
#       <td>38.016816</td>
#       <td>661.584537</td>
#       <td>16269.0</td>
#     </tr>
#     <tr>
#       <th>SlBielSterni</th>
#       <td>49.806389</td>
#       <td>19.023194</td>
#       <td>105.596815</td>
#       <td>1578.592036</td>
#       <td>32531.0</td>
#     </tr>
#     <tr>
#       <th>SlCzestoZana</th>
#       <td>50.801918</td>
#       <td>19.106961</td>
#       <td>43.316778</td>
#       <td>1652.216482</td>
#       <td>39671.0</td>
#     </tr>
#     <tr>
#       <th>SlGliwicMewy</th>
#       <td>50.279481</td>
#       <td>18.655736</td>
#       <td>102.722112</td>
#       <td>1071.352547</td>
#       <td>22

# %% [markdown]
# We perform this one more time to add locations with errors

# %%
import geopandas as gpd
import pandas as pd
import osmnx as ox
from shapely.geometry import Point
import numpy as np

# konfiguracja
ox.settings.use_cache = True
ox.settings.log_console = False

buffer_radius = 5000  # m

def compute_features(lat, lon, buffer_radius=2000):
    try:
        # Tworzymy punkt i bufor (buffer_geometry automatycznie konwertuje do metrycznego CRS)
        pt = Point(lon, lat)  # shapely: (lon, lat)
        buffer_poly = ox.utils_geo.buffer_geometry(pt, buffer_radius)

        # Konwersje do EPSG:3857 tylko raz
        buffer_3857 = gpd.GeoSeries([buffer_poly], crs="EPSG:4326").to_crs(epsg=3857).iloc[0]
        pt_3857 = gpd.GeoSeries([pt], crs="EPSG:4326").to_crs(epsg=3857).iloc[0]

        # === DROGI ===
        try:
            G = ox.graph_from_point((lat, lon), dist=buffer_radius, network_type="drive")
            _, edges = ox.graph_to_gdfs(G)
            edges = edges.to_crs(epsg=3857)

            edges_in = edges[edges.geometry.intersects(buffer_3857)]
            total_road_length_km = edges_in.length.sum() / 1000 if not edges_in.empty else np.nan
            nearest_road_dist_m = edges_in.distance(pt_3857).min() if not edges_in.empty else np.nan

        except Exception as e:
            print(f"[Błąd dróg] ({lat}, {lon}): {e}")
            total_road_length_km = np.nan
            nearest_road_dist_m = np.nan

        # === BUDYNKI ===
        try:
            # Uwaga: 'True' w OSMnx filtruje wszystkie budynki, ale w starych wersjach trzeba podać listę wartości
            buildings = ox.features_from_polygon(buffer_poly, tags={"building": True})
            buildings = buildings[buildings.geometry.geom_type.isin(["Polygon", "MultiPolygon"])]

            buildings = buildings.to_crs(epsg=3857)
            buildings_in = buildings[buildings.geometry.intersects(buffer_3857)]
            building_count = len(buildings_in) if not buildings_in.empty else 0

        except Exception as e:
            print(f"[Błąd budynków] ({lat}, {lon}): {e}")
            building_count = np.nan

        return nearest_road_dist_m, total_road_length_km, building_count

    except Exception as e:
        print(f"[Błąd ogólny] ({lat}, {lon}): {e}")
        return np.nan, np.nan, np.nan


df_meta = pd.read_csv("metadata5000.csv")
# Filtrujemy tylko wiersze, w których przynajmniej jedna z kolumn wynikowych ma NaN
rows_to_process = df_meta[
    df_meta[["nearest_road_dist_m", "total_road_length_km", "building_count"]].isna().any(axis=1)
]

x = 1
for i, row in rows_to_process.iterrows():
    nr, trl, bc = compute_features(row.lat, row.lon, buffer_radius)
    df_meta.at[i, "nearest_road_dist_m"] = nr
    df_meta.at[i, "total_road_length_km"] = trl
    df_meta.at[i, "building_count"] = bc
    print(f"Przetworzono {x}/{len(rows_to_process)} lokalizacji")
    x += 1
# Out:
# Przetworzono 1/7 lokalizacji
# Przetworzono 2/7 lokalizacji
# Przetworzono 3/7 lokalizacji
# Przetworzono 4/7 lokalizacji
# Przetworzono 5/7 lokalizacji
# Przetworzono 6/7 lokalizacji
# Przetworzono 7/7 lokalizacji

# %%
from IPython.display import display, HTML

# przykład dla DataFrame
display(HTML(f"<div style='max-height:300px; overflow:auto;'>{df_meta.to_html()}</div>"))

df_meta
df_meta.to_csv('metadata5000best.csv')
# Out:
# <div style='max-height:300px; overflow:auto;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>nearest_road_dist_m</th>
#       <th>total_road_length_km</th>
#       <th>building_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>DsLegAlRzecz</td>
#       <td>51.204503</td>
#       <td>16.180513</td>
#       <td>98.613062</td>
#       <td>942.949585</td>
#       <td>15745.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>DsOsieczow21</td>
#       <td>51.317630</td>
#       <td>15.431719</td>
#       <td>40.258760</td>
#       <td>148.954010</td>
#       <td>2334.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>DsWalbrzWyso</td>
#       <td>50.768729</td>
#       <td>16.269677</td>
#       <td>170.100903</td>
#       <td>817.813995</td>
#       <td>15897.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>DsWrocNaGrob</td>
#       <td>51.103456</td>
#       <td>17.059225</td>
#       <td>97.176639</td>
#       <td>1518.020860</td>
#       <td>60249.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>DsZgorBohGet</td>
#       <td>51.150391</td>
#       <td>15.008175</td>
#       <td>138.987771</td>
#       <td>988.524194</td>
#       <td>28363.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>KpBydFieldor</td>
#       <td>53.151452</td>
#       <td>18.132062</td>
#       <td>22.380118</td>
#       <td>711.014879</td>
#       <td>8995.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>KpGrudSienki</td>
#       <td>53.491831</td>
#       <td>18.752503</td>
#       <td>108.389527</td>
#       <td>765.180131</td>
#       <td>22104.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>KpToruDziewu</td>
#       <td>53.028647</td>
#       <td>18.666103</td>
#       <td>97.101206</td>
#       <td>1339.475703</td>
#       <td>21483.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>KpZielBoryTu</td>
#       <td>53.662117</td>
#       <td>17.934017</td>
#       <td>155.819124</td>
#       <td>123.469175</td>
#       <td>665.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>LbBiaPodOrze</td>
#       <td>52.029194</td>
#       <td>23.149389</td>
#       <td>28.987375</td>
#       <td>888.236469</td>
#       <td>16920.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>LbChelJagiel</td>
#       <td>51.130950</td>
#       <td>23.514603</td>
#       <td>32.203574</td>
#       <td>763.408153</td>
#       <td>15088.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>LbLubSliwins</td>
#       <td>51.273078</td>
#       <td>22.551675</td>
#       <td>73.295668</td>
#       <td>1620.709864</td>
#       <td>28988.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>LbZamoHrubie</td>
#       <td>50.716628</td>
#       <td>23.290247</td>
#       <td>49.634154</td>
#       <td>809.140780</td>
#       <td>17611.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>LdLodzCzerni</td>
#       <td>51.758050</td>
#       <td>19.529786</td>
#       <td>110.091454</td>
#       <td>1384.584774</td>
#       <td>32623.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>LdLodzLegion</td>
#       <td>51.776417</td>
#       <td>19.452936</td>
#       <td>37.578384</td>
#       <td>1859.101610</td>
#       <td>57117.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>LdPioTrKraPr</td>
#       <td>51.404406</td>
#       <td>19.696956</td>
#       <td>49.362299</td>
#       <td>940.236024</td>
#       <td>18860.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>LuGorzPilsud</td>
#       <td>52.747044</td>
#       <td>15.246294</td>
#       <td>223.310025</td>
#       <td>1039.190473</td>
#       <td>23111.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>LuZarySzyman</td>
#       <td>51.642656</td>
#       <td>15.127808</td>
#       <td>110.791073</td>
#       <td>599.697384</td>
#       <td>11614.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>LuZielKrotka</td>
#       <td>51.939783</td>
#       <td>15.518861</td>
#       <td>25.056820</td>
#       <td>1101.224200</td>
#       <td>21051.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>MpBochKonfed</td>
#       <td>49.969017</td>
#       <td>20.439511</td>
#       <td>12.025842</td>
#       <td>783.667809</td>
#       <td>14474.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>MpKrakBujaka</td>
#       <td>50.010575</td>
#       <td>19.949189</td>
#       <td>38.535320</td>
#       <td>1600.690043</td>
#       <td>45528.0</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>MpNoSaczNadb</td>
#       <td>49.619281</td>
#       <td>20.714403</td>
#       <td>217.636022</td>
#       <td>1107.655265</td>
#       <td>23213.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>MpTarBitStud</td>
#       <td>50.020169</td>
#       <td>21.004167</td>
#       <td>31.005101</td>
#       <td>1231.287945</td>
#       <td>22721.0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>MpTrzebOsZWM</td>
#       <td>50.159406</td>
#       <td>19.477464</td>
#       <td>46.772680</td>
#       <td>639.941377</td>
#       <td>13759.0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>MpZakopaSien</td>
#       <td>49.293564</td>
#       <td>19.960083</td>
#       <td>193.943484</td>
#       <td>429.647756</td>
#       <td>13466.0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>MzPlocKroJad</td>
#       <td>52.556279</td>
#       <td>19.687672</td>
#       <td>161.042518</td>
#       <td>896.545491</td>
#       <td>16202.0</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>MzRadHallera</td>
#       <td>51.415324</td>
#       <td>21.171285</td>
#       <td>166.962547</td>
#       <td>1432.618227</td>
#       <td>37640.0</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>MzWarKondrat</td>
#       <td>52.290864</td>
#       <td>21.042458</td>
#       <td>131.015057</td>
#       <td>1651.564140</td>
#       <td>32941.0</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>MzWarWokalna</td>
#       <td>52.160772</td>
#       <td>21.033819</td>
#       <td>257.648262</td>
#       <td>1698.648574</td>
#       <td>25251.0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>OpKluczMicki</td>
#       <td>50.972181</td>
#       <td>18.207575</td>
#       <td>228.059519</td>
#       <td>504.617552</td>
#       <td>9836.0</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>OpOpoleOsAKr</td>
#       <td>50.676856</td>
#       <td>17.950278</td>
#       <td>296.021447</td>
#       <td>1032.870120</td>
#       <td>25485.0</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>PdBialWarsza</td>
#       <td>53.129306</td>
#       <td>23.181744</td>
#       <td>305.461035</td>
#       <td>1732.771180</td>
#       <td>34926.0</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>PdLomSikorsk</td>
#       <td>53.181394</td>
#       <td>22.054381</td>
#       <td>42.572434</td>
#       <td>799.896652</td>
#       <td>16502.0</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>PkJasloSikor</td>
#       <td>49.744886</td>
#       <td>21.454617</td>
#       <td>17.311975</td>
#       <td>737.736878</td>
#       <td>17077.0</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>PkKrosKletow</td>
#       <td>49.690169</td>
#       <td>21.749700</td>
#       <td>151.998078</td>
#       <td>825.462911</td>
#       <td>20298.0</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>PkNiskoSzkla</td>
#       <td>50.529892</td>
#       <td>22.112467</td>
#       <td>12.798185</td>
#       <td>621.648386</td>
#       <td>12447.0</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>PkRzeszRejta</td>
#       <td>50.024242</td>
#       <td>22.010575</td>
#       <td>70.808989</td>
#       <td>1495.991239</td>
#       <td>40593.0</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>PmGdaPowWiel</td>
#       <td>54.398639</td>
#       <td>18.614333</td>
#       <td>164.603097</td>
#       <td>1146.518474</td>
#       <td>25932.0</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>PmKosTargowa</td>
#       <td>54.120694</td>
#       <td>17.975861</td>
#       <td>34.574882</td>
#       <td>698.759853</td>
#       <td>10644.0</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>SkBuskRokosz</td>
#       <td>50.453621</td>
#       <td>20.715640</td>
#       <td>188.513671</td>
#       <td>600.829401</td>
#       <td>12721.0</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>SkKielWarsza</td>
#       <td>50.894374</td
